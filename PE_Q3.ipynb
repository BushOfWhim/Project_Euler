# %% [markdown]
# Problem 3
#
# The prime factors of 13195 are 5, 7, 13 and 29.
#
# What is the largest prime factor of the number 600851475143 ?

# %%
#WIP

#start with 2
#is it a factor
#do we need another factor
#find the next prime number

prime_array= [2]
factors = []
product_factor = 1

def next_prime(prime_array):
    nxt = prime_array[-1] + 1
    while is_it_a_prime(nxt) == 'no':
        nxt += 1
    print(len(prime_array))
#    print(prime_array)
        
def is_it_a_prime(new_no):
    i = 0
    while i <= len(prime_array)-1 and prime_array[i] <= (new_no/2):
        if new_no % prime_array[i] == 0:
            return 'no'
        else:
            i +=1
    #if i == len(prime_array) or new_no/2 > prime_array[i]:
    prime_array.append(new_no)
    return 'yes'

def next_factor(target):
    if (target/product_factor) % prime_array[-1] !=0:
        next_prime(prime_array)
        if target % prime_array[-1] == 0:
            factors.append(prime_array[-1])
            find_product(factors,product_factor)
            print(factors)
            print(product_factor)
    else:
        factors.append(prime_array[-1])
        find_product(factors,product_factor)
    #next_prime(prime_array)
    print(factors)
    print(target - product_factor)

def find_product(factors,product_factor): 
    #product_factor = 1
    for j in factors:
        product_factor = j * product_factor
        #return product_factor
    
def find_largest_factor(target):
    while product_factor != target:
        #find next factor
        #check = target % numpy.prod(factors)
        #if is_it_a_prime(check) == 'yes':
        #    factors.append(check)
        #else:
        print('product')
        print(product_factor)
        print(target)
        next_factor(target)

    print(factors)        
    print(factors[-1])


find_largest_factor(600851475143)  #600851475143
